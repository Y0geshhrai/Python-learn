# %% [markdown]
# ## Integer

# %% [markdown]
# ## question 1, checking odd or even

# %%
number = int(input("enter your number :"))
if number % 2 ==0:
    print(f"your number {number} is even")
else:
    print(f"your number {number} is odd")
# Out:
# your number 3 is odd

# %% [markdown]
# ## question 2, checking if number is multiple of 3 and 5

# %%
num = int(input("enter your numbers:"))
if num % 3==0 and num % 5==0:
    print(num,"is multiple of 3 and 5")
else:
    print(num,"is not multiple of 3 and 5")
# Out:
# 30 is multiple of 3 and 5

# %% [markdown]
# ## question 3, checking no. is p+ve , n-ve , zero

# %%
num = int(input("Enter your number"))
if num >0:
    print(f"your number {num} is positive.")
elif num <=-1:
    print(f"your number {num} is  negative.")
else:
    print(f"your number {num} is zero.")
# Out:
# your number -12 is  negative.

# %% [markdown]
# ## question 4, finding largest among 3 integers

# %%
num1 = int(input("enter your first number"))
num2 = int(input("enter your second number"))
num3 = int(input("enter your third number"))
if num1 >= num2 and num1 >= num3:
    print(f"entered number num1 {num1} is gretest")
elif num2 >= num1 and num2 >= num3:
    print(f"entered number num2 {num2} is gretest")
else:
    print(f"enter number num3 {num3} is gretest")
# Out:
# enter number num3 4 is gretest

# %%
#using max() function
num1 = int(input("enter your first number"))
print("first number is :",num1)
num2 = int(input("enter your second number"))
print("first number is :",num2)
num3 = int(input("enter your third number"))
print("first number is :",num3)
greatest = max(num1 , num2 , num3)
print("the greatest among threee is",greatest)
# Out:
# first number is : -12
# first number is : 5
# first number is : -3
# the greatest among threee is 5

# %%
numbers = []
for i in range(3):
    num = int(input("enter your number :"))
    numbers.append(num)
greatest = max(numbers)
print("the greatest number is: ",greatest)
# Out:
# the greatest number is:  4

# %% [markdown]
# ## question 5, checking no's a prime

# %%
#using range function
num = int(input("enter a number: "))

if num <= 1:
    print(f"{num} is not a prime number")
else:
    for i in range(2,num):
        if num % i ==0:
            print(f"{num} is not a prime number")
            break
    else:
        print(f"{num} is a prime number")
# Out:
# 6 is not a prime number

# %% [markdown]
# ## question 6, number within range

# %%
#using range function
num = int(input("enter the number"))
if num in range(100,1000):
    print(f"{num} is in range of 100 - 999 ")
else:
    print(f"{num} is not in range of 100 - 999")
# Out:
# 10 is not in range of 100 - 999

# %%
num = int(input("enter the number"))
if 100 <= num <=999:
    print(f"{num} is in range of 100-999")
else:
    print(f"{num} is not in range of 100 - 999")
# Out:
# 150 is in range of 100-999

# %% [markdown]
# ## question 7, cheching sum of two integers is greater than 50

# %%
num1 = int(input("enter your first number: "))
num2 = int(input("enter your second number"))
if num1+num2 > 50:
    print(f"the sum of num1 {num1} and num2 {num2} is greater than 50.")
else:
    print(f"the sum of num1 {num1} and num2 {num2} is not greater than 50")
# Out:
# the sum of num1 10 and num2 10 is not greater than 50

# %%
#using sum() function
num1 = int(input("enter your first number: "))
num2 = int(input("enter your second number"))
if sum ([num1,num2]) > 50:
    print(f"the sum of num1 {num1} and num2 {num2} is greater than 50.")
else:
    print(f"the sum of num1 {num1} and num2 {num2} is not greater than 50")
# Out:
# the sum of num1 40 and num2 39 is greater than 50.

# %% [markdown]
# ## question 8, divisible by 4 but not by 8 , print"special"

# %%
num = int(input("enter the number"))
if num % 4 ==0 and num % 8 !=0:
    print("special")
else:
    print("not special")
# Out:
# special

# %% [markdown]
# ## question 9, comparing two numbers and printing "Equal", "Greatest" of "Smaller"

# %%
num1 = int(input("enter first number"))
num2 = int(input("enter second number"))
if num1==num2:
    print("Equal")
elif num1>num2:
    print("Greater")
else:
    print("Smaller")
# Out:
# Equal

# %% [markdown]
# ## question 10,  classify age

# %%
age = int(input("Enter age: "))

if 0 <= age <= 12:
    print("Child")
elif 13 <= age <= 19:
    print("Teen")
elif 20 <= age <= 59:
    print("Adult")
elif age >= 60:
    print("Senior")
else:
    print("Invalid age")
# Out:
# Invalid age
